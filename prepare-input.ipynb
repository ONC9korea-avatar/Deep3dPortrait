# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.io import loadmat, savemat
import cv2 as cv

import os

# %%
name = '1_1234'

# %%
img = cv.imread(os.path.join('input', name+'.jpeg'))
h, w, *_ = img.shape


lm = np.loadtxt(os.path.join('input', name+'_landmark.txt')).reshape((-1, 2))
lm = np.stack([lm[:,0], h - 1 - lm[:,1]], axis = 1)

plt.imshow(img[:,:,::-1])
plt.scatter(*lm.T, s=3)
